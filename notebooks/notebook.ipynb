# %%
import pandas as pd

# %%
df  = pd.read_csv("/Users/balavishnu/Desktop/Datascience/Handgesture_project/data/raw/hand_gesture_dataset.csv")

# %%
df.head()
# Out:
#           0         1             2         3         4         5         6  \
# 0  0.181233  0.862510  7.851402e-07  0.245704  0.778000 -0.062096  0.276088
# 1  0.222495  0.672709  5.193123e-07  0.293542  0.576038 -0.036413  0.323402
# 2  0.233527  0.744601  9.757975e-07  0.297516  0.601007 -0.023088  0.318541
# 3  0.403786  0.670779  6.061386e-07  0.486460  0.624574 -0.049359  0.557192
# 4  0.426507  0.740725  7.742443e-07  0.521746  0.683856 -0.045136  0.587266
#
#           7         8         9  ...        54        55        56        57  \
# 0  0.651717 -0.086765  0.268893  ... -0.004389  0.558987 -0.076295 -0.017370
# 1  0.450394 -0.049646  0.330697  ...  0.017118  0.331314 -0.076217 -0.009410
# 2  0.460952 -0.030140  0.315490  ...  0.026835  0.389238 -0.031023  0.013525
# 3  0.512463 -0.069122  0.589737  ...  0.257362  0.271876 -0.074717  0.249029
# 4  0.558678 -0.060945  0.614740  ...  0.306805  0.300253 -0.067985  0.302054
#
# ...

# %%
df["label"].unique()
# Out:
# array(['ok', 'palm', 'point', 'rock', 'victory'], dtype=object)

# %%
df.isna().sum()
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 59       0
# 60       0
# 61       0
# 62       0
# label    0
# Length: 64, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# %%
X = df.iloc[:, :-1].values
y = df["label"].values

encoder = LabelEncoder()
y = encoder.fit_transform(y)

# %%
y
# Out:
# array([0, 0, 0, ..., 4, 4, 4])

# %%
X
# Out:
# array([[ 1.81232542e-01,  8.62510324e-01,  7.85140230e-07, ...,
#         -2.43732780e-02,  4.22045469e-01, -9.16807204e-02],
#        [ 2.22494543e-01,  6.72708869e-01,  5.19312323e-07, ...,
#         -3.04750204e-02,  2.00861678e-01, -9.49704871e-02],
#        [ 2.33527482e-01,  7.44601011e-01,  9.75797548e-07, ...,
#          7.70556927e-03,  2.70859152e-01, -3.15102637e-02],
#        ...,
#        [ 5.22249103e-01,  8.63269508e-01,  1.13536817e-06, ...,
#          6.11971140e-01,  6.59442782e-01, -9.89306867e-02],
#        [ 5.26031315e-01,  8.70218277e-01,  1.14340537e-06, ...,
#          6.18435144e-01,  6.70974612e-01, -1.01834208e-01],
#        [ 5.34321308e-01,  9.07985687e-01,  1.15549346e-06, ...,
#          6.24306858e-01,  7.02696919e-01, -1.05546318e-01]])
